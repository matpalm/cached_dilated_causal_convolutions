# %%
import pickle
from collections import Counter
import numpy as np

# %%
D = '/home/mat/dev/cached_dilated_causal_convolutions/runs/37_po2_regression_8d_64d/weights/qkeras/e09.pkl'

with open(D, 'rb') as f:
    weights = pickle.load(f)

po2a = weights['qconv_1_1a_po2']['weights'][0]
po2b = weights['qconv_1_1b_po2']['weights'][0]

print(po2a.shape, po2b.shape)

# %%
len(Counter(po2a.flatten()))

# %%
len(Counter(po2b.flatten()))

# %%
po2ab = np.matmul(po2a, po2b)
len(Counter(po2ab.flatten()))

# %%
16*16

# %%
64/16
