# %%
# %cd ..

# %%
import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("../loss_log.tsv", sep="\t")
df.describe()

# %%
df[df.freq==53]

# %%
sns.histplot(data=df[df.epoch==20], x='loss', hue='eg_type')

# %%
df[df.idx==112]
